# %% [markdown]
# # AI learning task 2

# %% [markdown]
# ### Question No. 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("Wuzzuf_Jobs.csv")

# %%
dataset.head()
# Out:
#                                Title                Company    Location  \
# 0             Customer Service Agent       Johnson Controls   New Cairo
# 1                  Marketing Manager  SYE English Community       Dokki
# 2  Medical Representative Heliopolis        So Value Pharma       Cairo
# 3          Order Handling Specialist       Johnson Controls   New Cairo
# 4                        Storekeeper           Confidential       Cairo
#
#         Type        Level         YearsExp Country  \
# 0  Full Time  Entry Level   1-3 Yrs of Exp   Cairo
# 1  Full Time      Manager  5-10 Yrs of Exp    Giza
# 2  Full Time  Entry Level   0-5 Yrs of Exp   Egypt
# 3  Full Time  Experienced   3-5 Yrs of Exp   Cairo
# 4  Full Time  Experienced    3+ Yrs of Exp   Egypt
#
#                                               Skills
# 0  Call Center, Customer Support, Customer Care, ...
# 1  Market Research, Social Media, Online Marketin...
# 2  Cardio-metabolic, Sales Skills, Sales Target, ...
# 3  Supply Officer, Supply Planner, Procurement an...
# 4  Warehousing, Storekeeping, Logistics/Supply Chain

# %%
x = dataset.iloc[:,5 ].values
x
# Out:
# array(['1-3 Yrs of Exp', '5-10 Yrs of Exp', '0-5 Yrs of Exp', ...,
#        '3-7 Yrs of Exp', '5+ Yrs of Exp', '3-7 Yrs of Exp'], dtype=object)

# %%
dataset["factorizedYearsExp"] = pd.factorize(dataset["YearsExp"])[0]
dataset.head()
# Out:
#                                Title                Company    Location  \
# 0             Customer Service Agent       Johnson Controls   New Cairo
# 1                  Marketing Manager  SYE English Community       Dokki
# 2  Medical Representative Heliopolis        So Value Pharma       Cairo
# 3          Order Handling Specialist       Johnson Controls   New Cairo
# 4                        Storekeeper           Confidential       Cairo
#
#         Type        Level         YearsExp Country  \
# 0  Full Time  Entry Level   1-3 Yrs of Exp   Cairo
# 1  Full Time      Manager  5-10 Yrs of Exp    Giza
# 2  Full Time  Entry Level   0-5 Yrs of Exp   Egypt
# 3  Full Time  Experienced   3-5 Yrs of Exp   Cairo
# 4  Full Time  Experienced    3+ Yrs of Exp   Egypt
#
#                                               Skills  factorizedYearsExp
# 0  Call Center, Customer Support, Customer Care, ...                   0
# 1  Market Research, Social Media, Online Marketin...                   1
# 2  Cardio-metabolic, Sales Skills, Sales Target, ...                   2
# 3  Supply Officer, Supply Planner, Procurement an...                   3
# 4  Warehousing, Storekeeping, Logistics/Supply Chain                   4

# %% [markdown]
# ### Question No. 2
#
# **first we encode the two columns into numbers**

# %%
dataset["Title"]= pd.factorize(dataset["Title"])[0]
dataset["Company"]= pd.factorize(dataset["Company"])[0]
dataset.head()
# Out:
#    Title  Company    Location       Type        Level         YearsExp  \
# 0      0        0   New Cairo  Full Time  Entry Level   1-3 Yrs of Exp
# 1      1        1       Dokki  Full Time      Manager  5-10 Yrs of Exp
# 2      2        2       Cairo  Full Time  Entry Level   0-5 Yrs of Exp
# 3      3        0   New Cairo  Full Time  Experienced   3-5 Yrs of Exp
# 4      4        3       Cairo  Full Time  Experienced    3+ Yrs of Exp
#
#   Country                                             Skills  \
# 0   Cairo  Call Center, Customer Support, Customer Care, ...
# 1    Giza  Market Research, Social Media, Online Marketin...
# 2   Egypt  Cardio-metabolic, Sales Skills, Sales Target, ...
# 3   Cairo  Supply Officer, Supply Planner, Procurement an...
# 4   Egypt  Warehousing, Storekeeping, Logistics/Supply Chain
#
#    factorizedYearsExp
# 0                   0
# 1                   1
# 2                   2
# 3                   3
# 4                   4

# %%
y = dataset.iloc[:, [0,1]].values
y
# Out:
# array([[   0,    0],
#        [   1,    1],
#        [   2,    2],
#        ...,
#        [2963, 1533],
#        [2048,  133],
#        [2964, 1533]], dtype=int64)

# %%
from sklearn.cluster import KMeans

# %%
wcss = []
for i in range(1, 21):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(y)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 21), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
from kneed import KneeLocator
K = KneeLocator(range(1, 21), wcss, curve="convex", direction="decreasing")
print(f"the best number of clusters is {K.elbow}")
# Out:
# the best number of clusters is 5

# %%
kmeans = KMeans(n_clusters= 5, init= 'k-means++', random_state=42)
y_kmeans = kmeans.fit_predict(y)
plt.subplots(figsize=(20, 6))
colors = ["red", "purple", "yellow", "teal","olive", "gray"]
for i in range(5):
    plt.scatter(y[y_kmeans == i, 0], y[y_kmeans == i, 1], s=100, c = colors[i], label = f'Cluster {i+1}')
#     plt.scatter(X[y_kmeans == i, 0], X[y_kmeans == i, 1], s=100, c=color_list[i], label=f'Cluster{i+1}')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c=colors[5], label='Centroids')
plt.title('Clusters of Jobs')
plt.xlabel('Jobs')
plt.ylabel('Companies')
plt.legend()
plt.show()
